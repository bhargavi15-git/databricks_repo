// %% [markdown]
// 🔹 1️⃣ Row-level operations
// - df.filter("amount > 1000")
// - df.where("status = 'SUCCESS'")
// - df.limit(100)
// - df.orderBy("txn_date")
// - df.sort("amount", ascending=False)
//
// 🔹 2️⃣ Column operations
// - df.select("id", "amount")
// - df.selectExpr("id", "amount * 1.1 as tax")
// - df.withColumn("year", year("txn_date"))
// - df.withColumnRenamed("amt", "amount")
// - df.drop("temp_col")
//
// 🔹 3️⃣ Aggregations & Grouping
// - df.groupBy("country").count()
// - df.groupBy("country").sum("amount")
// - df.agg({"amount": "avg"})
//
//
// With expressions:
//
// from pyspark.sql.functions import sum, avg
//
// df.groupBy("country").agg(
//     sum("amount").alias("total"),
//     avg("amount").alias("avg_amt")
// )
//
// 🔹 4️⃣ Joins (VERY common)
// df1.join(df2, "id", "inner")
// df1.join(df2, df1.id == df2.user_id, "left")
//
//
// Join types:
//
// inner, left, right, full, left_semi, left_anti
//
// 🔹 5️⃣ Deduplication & Set operations
// df.distinct()
// df.dropDuplicates(["id"])
//
// 🔹 6️⃣ Window functions
// from pyspark.sql.window import Window
// from pyspark.sql.functions import row_number
//
// w = Window.partitionBy("user").orderBy("txn_date")
//
// df.withColumn("rn", row_number().over(w))
//
// 🔹 7️⃣ Performance & execution control
// - df.cache()
// - df.persist()
// - df.repartition(10)
// - df.coalesce(5)
// - df.explain()
//
// 🔹 8️⃣ Metadata & debugging
// - df.printSchema()
// - df.show()
// - df.count()
// - df.columns
// - df.dtypes
//
// 🔹 9️⃣ Writing the result (end of pipeline)
// - df.write.mode("overwrite").saveAsTable("sales.summary")
// - df.write.parquet("/data/output/")
