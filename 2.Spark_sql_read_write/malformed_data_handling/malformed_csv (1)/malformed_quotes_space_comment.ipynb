// %%
%python

df1=spark.read.schema(schema1).csv("/Volumes/inceptez_data/inceptez_data/malformed_data/source3.txt",inferSchema=True,comment='#',sep='~',ignoreLeadingWhiteSpace=True,ignoreTrailingWhiteSpace=True,quote="'",dateFormat='dd-MM-yyyy',timestampFormat='HH:mm:ss',escape="\\",multiLine=True)
display(df1)

// %%
%python
df1=spark.read.parquet()
