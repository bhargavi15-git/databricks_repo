// %%
%python
schema1 = "id int, name string,location string, age int,desc string,salary double"
df1=spark.read.schema(schema1).csv("/Volumes/inceptez_data/inceptez_data/malformed_data/source2.txt",comment='#',sep='~',nullValue='na',nanValue="-1",emptyValue="abc")
display(df1)
