// %%
%python
dbutils.widgets.text("Name","Bhargavi","Enter your Name")
dbutils.widgets.text("Age","25","Enter your Age")
print(dbutils.widgets.get("Name"))
print(dbutils.widgets.get("Age"))
dbutils.notebook.exit("Success")
