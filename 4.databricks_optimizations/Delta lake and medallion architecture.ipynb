# %% [markdown]
# ###Delta Lake architecture
# ![image_1770295299904.png](./image_1770295299904.png "image_1770295299904.png")
#
# ![image_1770296715014.png](./image_1770296715014.png "image_1770296715014.png")

# %% [markdown]
# ###Medallion architecture vs Traditional Datawarehouse
#
# ![image_1770297549902.png](./image_1770297549902.png "image_1770297549902.png")
