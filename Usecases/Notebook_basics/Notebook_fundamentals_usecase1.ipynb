// %% [markdown]
// # $$\textcolor{blue}{\text{Databricks Fundamentals}}$$
//
// This will automatically appear centered.MathJax centers automatically only if you use block math.

// %% [markdown]
// ##Learning to work on notebook

// %% [markdown]
// ###Designing Notebooks using Markdown:
// - Creating headers and subheaders(Subheaders can go upto 6 level)
// - Creating **Bold** text
// - Creating _Italic_ text
// - Inserting URLs like [Image_URL]("https://fpimages.withfloats.com/actual/6929d1ac956d0a744b5c9822.jpeg")
// - Inseting Images like ![](https://fpimages.withfloats.com/actual/6936e213e40c3ddda3969dd0.jpeg)
// - Inserting Bullet List
// - Creating Coloured Text with bold: $${\color{blue}\textbf{Blue}}$$ $${\color{red}\textbf{red}}$$
// - Creating Coloured Text:$${\color{blue}\text{Blue}}$$ $${\color{red}\text{red}}$$
// - Creating Coloured Text:$$\textcolor{blue}{\textit{Blue}}$$  $$\textcolor{red}{\textit{red}}$$

// %% [markdown]
// ###Creating Volumes with SQL command

// %%
%sql
CREATE VOLUME IF NOT EXISTS workspace.default.usage_metrics;

// %% [markdown]
// ###Checking the created volume with fs commands

// %%
%fs ls "/Volumes/workspace/default/usage_metrics"
%fs ls "dbfs:////Volumes/workspace/default/usage_metrics"

// %% [markdown]
// ###Running a child notebook

// %%
%run "/Workspace/inceptez-learning/databricks_learning/My_Child_Notebook"

// %% [markdown]
// ### More fs commands:

// %%
%fs ls dbfs:////Volumes/workspace/default/usage_metrics

// %%
%python
print(
  dbutils.fs.head(
    "dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",
    1000
  )
)

// %% [markdown]
// ### Creating DF

// %%
%python
df1=spark.read.csv("dbfs:/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv")
df1.write.mode("overwrite").saveAsTable("workspace.default.mobile_os_usage")

// %%
%python
spark.read.table("workspace.default.mobile_os_usage").display()

// %%
%sql
select * from workspace.default.mobile_os_usage

// %% [markdown]
// ###Playing with python code

// %%
%python
def upper_func(str1:str):
    return str1.upper()
upper_func("hello")

// %% [markdown]
// ###Working with Pip

// %%
%python
%pip install pandas

// %%
%python
pip install pandas

// %%
%python
dbutils.library.restartPython()

// %%
%python
import pandas as pd
pd.read_csv("/Volumes/workspace/default/usage_metrics/mobile_os_usage.csv").display()

// %%
%sh
echo "Magic commands tasks completed"

// %%
%sh ls /home
