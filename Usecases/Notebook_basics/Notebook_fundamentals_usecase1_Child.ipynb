// %%
%py

import requests
url = "https://public.tableau.com/app/sample-data/mobile_os_usage.csv"
my_data = requests.get(url)
dbutils.fs.put("dbfs:////Volumes/workspace/default/usage_metrics/mobile_os_usage.csv",my_data.text,overwrite=True)
